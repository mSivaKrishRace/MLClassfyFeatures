# %%
# %config IPCompleter.greedy=True

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import SGDClassifier
import numpy as np
import pandas as pd
import sys
import pickle
import csv

# %% [markdown]
# # Database_Sentence_Kannada_653_Samples

# %%
path_to_data = '/home/lenovo/All5_KannadaDataAug2018/5_Class_Sentc_Knd_Extracd_Features/'

max_classes = 5;
#Don't Edit this Below Code
max_classes += 1;

# %% [markdown]
# ##### Read the file.csv  in Text Mode
# - mode='rt' or mode='r'
#
#
# Here, Read the file.csv  in Text Mode to Extract the Contents in it using above code.

# %%
X_mfcc = []
Y_mfcc = []

# %% [markdown]
# ## CSV Not With PICKLE(PYTHON_eNCODING format)
# - If the CSV file is Not Generated using PICKLE then to OPEN the file is the following way:

# %% [markdown]
# with open(path_to_data + 'MFCC_Features/MFCC_features_' + str(max_classes-1) + '.csv',mode='rt') as fp:
#     X_Mfccs= csv.reader(fp, delimiter=',',quotechar='|')
#
#     for row in X_Mfccs:
#         if len(row)!= 0:
#             X_mfcc = X_mfcc + [row]
#
#     print(fp.closed)
# with open(path_to_data + 'MFCC_Features/MFCC_labels_' + str(max_classes-1) + '.csv',mode='rt') as fp:
#     y_labels = csv.reader(fp, delimiter=',',quotechar='|')
#
#     for row in y_labels:
#         if len(row)!= 0:
#             Y_mfcc = Y_mfcc + [row]
#
#     print(fp.closed)

# %% [markdown]
# #### Error - while trying to Open a "(pickle)"- Encoded CSV file
#  If U are trying to Open a "(pickle)"- Encoded CSV file, then this Error will Arise:
# - UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %% [markdown]
# ## Opening CSV file Encoded using "PICKLE"_PYTHON Encoding

# %% [markdown]
# ## MFCC__Features

# %% [markdown]
# #### Path_to_Features for Loading

# %%
with open(path_to_data + 'MFCC_Features/MFCC_labels_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    y_mfcc= pickle.load(fp)

    
with open(path_to_data + 'MFCC_Features/MFCC_features_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    X_mfcc= pickle.load(fp,encoding='latin1')

# %%
X_fs = np.array(X_mfcc)
Y_ls = np.array(y_mfcc)

# %%
X_fs.shape, Y_ls.shape
# Out:
# ((653, 40), (653,))

# %% [markdown]
# #### Splitting Data for TRAINing & TESTing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_fs,Y_ls, test_size=0.2,  random_state=0)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((522, 40), (522,), (131, 40), (131,))

# %% [markdown]
# ### SGDClassifier Models (for Classification of Dialects)

# %% [markdown]
# - Loss = hinge

# %%
clf_fold = SGDClassifier(loss="hinge", penalty="l2")

scores_sgd_m_hinge =cross_val_score(clf_fold,X_fs,Y_ls, cv=10)

scores_sgd_m_hinge
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.75      ,  0.86363636,  0.78787879,  0.84848485,  0.75384615,
#         0.73846154,  0.69230769,  0.84375   ,  0.703125  ,  0.71875   ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_sgd_m_hinge.mean(), scores_sgd_m_hinge.std() * 2))
# Out:
# Accuracy: 0.77 (+/- 0.12)

# %% [markdown]
# - loss = "log"

# %%
clf_Sgd_mh = SGDClassifier(loss="log", penalty="l2")

scores_Sgd_m_log =cross_val_score(clf_Sgd_mh,X_fs,Y_ls, cv=10)

scores_Sgd_m_log
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.75      ,  0.92424242,  0.8030303 ,  0.86363636,  0.87692308,
#         0.76923077,  0.8       ,  0.859375  ,  0.796875  ,  0.765625  ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_Sgd_m_log.mean(), scores_Sgd_m_log.std() * 2))
# Out:
# Accuracy: 0.82 (+/- 0.11)

# %% [markdown]
# - loss = "modified_huber"

# %%
clf_Sgd_mh = SGDClassifier(loss="modified_huber", penalty="l2")

scores_Sgd_mh_m =cross_val_score(clf_Sgd_mh,X_fs,Y_ls, cv=10)

scores_Sgd_mh_m
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.79411765,  0.72727273,  0.77272727,  0.89393939,  0.75384615,
#         0.78461538,  0.70769231,  0.859375  ,  0.734375  ,  0.828125  ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_Sgd_mh_m.mean(), scores_Sgd_mh_m.std() * 2))
# Out:
# Accuracy: 0.79 (+/- 0.11)

# %% [markdown]
# ## Delta_mfcc Features Path

# %% [markdown]
# #### Path_to_Features for Loading

# %%
with open(path_to_data + 'MFCC_Features/delta_labels_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    y_delta = pickle.load(fp)
with open(path_to_data + 'MFCC_Features/delta_features_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    X_delta = pickle.load(fp,encoding='latin1')

# %%
X_Dmfs = np.array(X_delta)
Y_Dls = np.array(y_delta)

# %%
X_Dmfs.shape, Y_Dls.shape
# Out:
# ((653, 40), (653,))

# %% [markdown]
# # For Features (Mfcc+Delta_Mfcc)

# %%
with open(path_to_data + 'MFCC_Features/MFCC_features_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    X_mfcc_653 = pickle.load(fp)

# %%
X_mfc = np.array(X_mfcc_653)

# %%
X_mfc.shape
# Out:
# (653, 40)

# %%
X_mf_Dmfs=np.concatenate((X_mfc,X_Dmfs),axis=1)

# %% [markdown]
# #### Splitting Data for TRAINing & TESTing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_mf_Dmfs,Y_Dls, test_size=0.2,  random_state=0)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((522, 80), (522,), (131, 80), (131,))

# %% [markdown]
# ### SGD Models (for Classification of Dialects)

# %% [markdown]
# - Loss = "Log"

# %%
clf_fold = SGDClassifier(loss="log", penalty="l2")

scores_sgd =cross_val_score(clf_fold,X_mf_Dmfs,Y_Dls, cv=10)

scores_sgd
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.77941176,  0.95454545,  0.86363636,  0.86363636,  0.78461538,
#         0.81538462,  0.70769231,  0.828125  ,  0.671875  ,  0.6875    ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_sgd.mean(), scores_sgd.std() * 2))
# Out:
# Accuracy: 0.80 (+/- 0.17)

# %% [markdown]
# - loss = "hinge"

# %%
clf_rbf = SGDClassifier(loss="hinge")

scores_hing_sgd_mplD =cross_val_score(clf_rbf,X_mf_Dmfs,Y_Dls, cv=10)

scores_hing_sgd_mplD
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.73529412,  0.75757576,  0.78787879,  0.78787879,  0.83076923,
#         0.83076923,  0.76923077,  0.765625  ,  0.734375  ,  0.75      ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_hing_sgd_mplD.mean(), scores_hing_sgd_mplD.std() * 2))
# Out:
# Accuracy: 0.77 (+/- 0.07)

# %% [markdown]
# - loss = "modified_huber"

# %%
clf_rbf = SGDClassifier(loss="modified_huber")

scores_hing_sgdmh_mplD =cross_val_score(clf_rbf,X_mf_Dmfs,Y_Dls, cv=10)

scores_hing_sgdmh_mplD
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.60294118,  0.72727273,  0.78787879,  0.86363636,  0.76923077,
#         0.93846154,  0.89230769,  0.765625  ,  0.65625   ,  0.75      ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_hing_sgdmh_mplD.mean(), scores_hing_sgdmh_mplD.std() * 2))
# Out:
# Accuracy: 0.78 (+/- 0.20)

# %% [markdown]
# ## Delta_Delta_mfcc Features

# %% [markdown]
# #### Path_to_Features for Loading

# %%
with open(path_to_data + 'MFCC_Features/delta2_labels_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    y_delta2 = pickle.load(fp)

with open(path_to_data + 'MFCC_Features/delta2_features_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    X_delta2 = pickle.load(fp,encoding='latin1')

# %%
X_DDmfs = np.array(X_delta2)
Y_DDls = np.array(y_delta2)

# %%
X_DDmfs.shape, Y_DDls.shape
# Out:
# ((653, 40), (653,))

# %% [markdown]
# # For Features (Mfcc+Delta_mfcc + DDmfcc)

# %%
X_mfcc_Dmfc_DDmfc=np.concatenate((X_mf_Dmfs,X_DDmfs),axis=1)

# %%
X_mfcc_Dmfc_DDmfc.shape
# Out:
# (653, 120)

# %% [markdown]
# #### Splitting Data for TRAINing & TESTing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_mfcc_Dmfc_DDmfc,Y_DDls, test_size=0.2,  random_state=0)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((522, 120), (522,), (131, 120), (131,))

# %% [markdown]
# ### SGD Models (for Classification of Dialects)

# %% [markdown]
# - Loss = "modified_huber"

# %%
clf_fold = SGDClassifier(loss="modified_huber", penalty="l2")

scores_sgd_dd =cross_val_score(clf_fold,X_mfcc_Dmfc_DDmfc,Y_DDls, cv=10)

scores_sgd_dd
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.66176471,  0.68181818,  0.86363636,  0.8030303 ,  0.76923077,
#         0.64615385,  0.72307692,  0.734375  ,  0.78125   ,  0.8125    ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_sgd_dd.mean(), scores_sgd_dd.std() * 2))
# Out:
# Accuracy: 0.75 (+/- 0.13)

# %% [markdown]
# - loss = "log"

# %%
clf_fold = SGDClassifier(loss="log", penalty="l2")

scores_sgd_dd_log =cross_val_score(clf_fold,X_mfcc_Dmfc_DDmfc,Y_DDls, cv=10)

scores_sgd_dd_log
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.82352941,  0.6969697 ,  0.66666667,  0.8030303 ,  0.76923077,
#         0.83076923,  0.52307692,  0.796875  ,  0.75      ,  0.890625  ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_sgd_dd_log.mean(), scores_sgd_dd_log.std() * 2))
# Out:
# Accuracy: 0.76 (+/- 0.20)

# %% [markdown]
# - loss="hinge"

# %%
clf_fold = SGDClassifier(loss="hinge", penalty="l2")

scores_sgd_dd_log =cross_val_score(clf_fold,X_mfcc_Dmfc_DDmfc,Y_DDls, cv=10)

scores_sgd_dd_log
# Out:
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# array([ 0.82352941,  0.84848485,  0.77272727,  0.75757576,  0.8       ,
#         0.72307692,  0.76923077,  0.796875  ,  0.796875  ,  0.75      ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_sgd_dd_log.mean(), scores_sgd_dd_log.std() * 2))
# Out:
# Accuracy: 0.78 (+/- 0.07)

# %% [markdown]
# ## All_Except_Chroma_Features

# %% [markdown]
# #### Path_to_Features for Loading

# %%
with open(path_to_data + 'All_Except_Chroma_Features/except_chroma_labels_' + str(max_classes-1) + '.txt',mode='rb') as fp: 
    y_all= pickle.load(fp)
    
with open(path_to_data + 'All_Except_Chroma_Features/except_chroma_features_X_new' + str(max_classes-1) + '.txt',mode='rb') as fp: 
    X_all= pickle.load(fp,encoding='latin1')

# %% [markdown]
# - Radial basis function - "rbf" Kernel

# %%
clf_all = SGDClassifier(loss="hinge", penalty="l2")

scores_sgd_all_h =cross_val_score(clf_all,X_all,y_all, cv=10)

scores_sgd_all_h
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-5a0a5f52ab6b> in <module>()
#       1 clf_all = SGDClassifier(loss="hinge", penalty="l2")
#       2
# ----> 3 scores_sgd_all_h =cross_val_score(clf_all,X_all,y_all, cv=10)
#       4
#       5 scores_sgd_all_h
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score)
#     190
#     191     """
# --> 192     X, y, groups = indexable(X, y, groups)
#     193
#     194     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [637, 683]

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_rbf_svm.mean(), scores_rbf_svm.std() * 2))
# Out:
# Accuracy: 0.76 (+/- 0.11)

# %%
X_all
# Out:
# [array([[  2.40471869e-02,   1.72413793e-02,   1.58802178e-02, ...,
#            8.16696915e-03,   1.86025408e-02,   3.22141561e-02],
#         [  1.68778675e-02,   7.37040048e-03,   8.31024054e-03, ...,
#            9.66581079e-04,   5.55297990e-04,   4.49725559e-04],
#         [  2.97369922e+00,   3.19197880e+00,   2.90472162e+00, ...,
#            3.21909251e+00,   2.97244791e+00,   2.97645357e+00],
#         ...,
#         [  1.79875318e-02,   1.45783490e-01,   3.79068032e-02, ...,
#            4.84266583e-03,   1.51398558e-02,   1.63656032e-02],
#         [  3.70672870e-02,   2.66924747e-03,   1.77208357e-02, ...,
#            6.86645891e-05,   2.38792455e-03,   1.07494336e-03],
#         [  1.03696735e-02,   3.85997307e-02,   4.73118480e-02, ...,
#            4.84414262e-02,   3.34017759e-02,   2.15835831e-02]]),
#  array([[  1.36116152e-02,   9.07441016e-03,   9.07441016e-03, ...,
#            6.21597096e-02,   2.90381125e-02,   2.81306715e-02],
#         [  4.39759421e-02,   5.34347824e-02,   8.08581807e-02, ...,
#            1.49542341e-02,   1.60941583e-02,   1.40492166e-02],
#         [  3.15697655e+00,   3.10845103e+00,   3.31143562e+00, ...,
#            3.27238958e+00,   3.26801936e+00,   3.28242545e+00],
#         ...,
#         [  8.34862781e-02,   5.70495981e-02,   7.32728567e-03, ...,
#            3.11888699e-03,   2.48142871e-03,   2.45490564e-03],
#         [  2.81877436e-02,   1.92185900e-02,   3.19323790e-02, ...,
#            3.80775366e-04,   4.11357588e-04,   4.54576033e-04],
#         [  3.52159534e-02,   5.09731344e-02,   7.44335275e-02, ...,
#            2.92472389e-02,   2.72445539e-02,   2.52451470e-02]]),
#  array([[  1.86025408e-02,   1.67876588e-02,   1.63339383e-02,
#            1.48820327e-01,   2.42740472e-01,   1.12068966e-01,
#            1.67876588e-02,   1.67876588e-02,   1.95099819e-02,
#            5.12704174e-02,   5.44464610e-02,   2.17785844e-02,
#            1.54264973e-02,   1.40653358e-02,   2.17785844e-02,
#            2.85843920e-02,   2.58620690e-02,   2.54083485e-02,
#            3.62976407e-02,   4.40108893e-02,   3.22141561e-02,
#            2.13248639e-02,   1.90562613e-02],
#         [  1.43757231e-01,   7.71514987e-02,   4.81526359e-02,
#            1.79376129e-02,   7.23146043e-03,   5.62851261e-02,
#            9.73131765e-02,   5.14821790e-02,   7.69710513e-03,
#            5.84777442e-03,   5.83642030e-02,   7.45229227e-02,
#            4.69953685e-02,   5.73213376e-02,   6.64145637e-02,
#            5.79811131e-02,   3.30758104e-02,   1.37992826e-02,
#            3.34172808e-03,   1.09048074e-03,   2.95061752e-02,
#            5.60270043e-02,   5.69089099e-02],
#         [  3.14805478e+00,   3.11067373e+00,   2.80676061e+00,
#            2.26205131e+00,   3.04409616e+00,   2.44585040e+00,
#            2.91040543e+00,   2.30733013e+00,   2.86134641e+00,
#            2.27141559e+00,   2.61483968e+00,   3.14035725e+00,
#            3.19171922e+00,   3.17099254e+00,   3.24747872e+00,
#            3.22650917e+00,   3.13973365e+00,   2.94749049e+00,
#            2.74838577e+00,   3.22206737e+00,   2.11451444e+00,
#            3.12362979e+00,   3.27277505e+00],
#         [  8.03733031e-02,   1.18470664e-01,   6.59726985e-02,
#            2.35116126e-01,   3.14580229e-01,   1.76142565e-01,
#            6.84077687e-02,   9.88071593e-02,   1.05830407e-01,
#            1.45760630e-01,   7.88282047e-02,   6.24938449e-02,
#            6.20732811e-02,   1.34472436e-01,   5.96605875e-02,
#            1.21698510e-01,   8.81399156e-02,   7.43301790e-02,
#            1.21188993e-01,   1.62004856e-01,   1.01557363e-01,
#            8.93084828e-02,   8.06597064e-02],
#         [  1.57775497e-01,   2.07669908e-01,   1.46271089e-01,
#            2.34920230e-01,   2.19066579e-01,   2.33033757e-01,
#            1.48954961e-01,   1.93454417e-01,   1.99835579e-01,
#            2.21355544e-01,   1.45928489e-01,   1.25013980e-01,
#            1.40236453e-01,   2.23796391e-01,   1.25129808e-01,
#            2.04961619e-01,   1.64904972e-01,   1.57106821e-01,
#            2.21962109e-01,   2.34413325e-01,   1.86986304e-01,
#            1.76562433e-01,   1.71644880e-01],
#         [  3.31407730e-02,   4.92374141e-02,   1.50270002e-02,
#            6.01794296e-01,   1.45325469e+00,   1.95794106e-01,
#            1.25249969e-02,   3.07347174e-02,   4.28829667e-02,
#            2.25588433e-01,   6.88795630e-02,   4.76392003e-02,
#            2.44821740e-02,   6.48520391e-02,   2.39871406e-02,
#            7.07719467e-02,   4.08823579e-02,   2.50091074e-02,
#            5.61710759e-02,   2.59875849e-01,   6.56609042e-02,
#            3.32829236e-02,   1.72642375e-02],
#         [  0.00000000e+00,   1.21188038e-02,   1.11250744e-02,
#            1.53814628e-02,   3.68380563e-03,   8.98189614e-03,
#            8.88282465e-03,   1.10802538e-02,   7.46858079e-03,
#            9.81837923e-03,   7.94766087e-03,   4.32117543e-03,
#            1.66407636e-02,   5.76751218e-03,   7.98089104e-03,
#            5.20669071e-03,   3.95236244e-03,   7.01386368e-03,
#            4.35669688e-03,   5.08007663e-03,   9.35666617e-03,
#            5.99398548e-03,   1.00632286e-02],
#         [  2.63157895e-02,   2.17785844e-02,   1.99637024e-02,
#            3.20326679e-01,   4.49183303e-01,   2.35934664e-02,
#            2.26860254e-02,   2.26860254e-02,   1.45190563e-02,
#            2.72232305e-02,   2.81306715e-02,   2.72232305e-02,
#            2.17785844e-02,   1.99637024e-02,   3.17604356e-02,
#            3.44827586e-02,   3.72050817e-02,   2.63157895e-02,
#            2.72232305e-02,   6.53357532e-02,   2.81306715e-02,
#            2.63157895e-02,   2.63157895e-02],
#         [ -2.18268736e+01,  -2.23698365e+01,  -2.41666091e+01,
#           -2.48348660e+01,  -2.64241357e+01,  -2.31152464e+01,
#           -2.38001093e+01,  -2.30823914e+01,  -2.62528818e+01,
#           -2.48299420e+01,  -2.28036802e+01,  -2.27698030e+01,
#           -2.41517028e+01,  -2.28152563e+01,  -2.27901575e+01,
#           -2.21703109e+01,  -2.32932951e+01,  -2.45328281e+01,
#           -2.64363376e+01,  -2.69512788e+01,  -2.31621239e+01,
#           -2.30785160e+01,  -2.34969330e+01],
#         [  3.14803336e+00,   3.02629823e+00,   4.22641194e+00,
#            3.73622607e+00,   3.27564837e+00,   3.73580616e+00,
#            4.23209327e+00,   3.89637989e+00,   3.38309923e+00,
#            2.91540233e+00,   3.29986043e+00,   3.56105109e+00,
#            3.72766792e+00,   3.10316188e+00,   3.47534363e+00,
#            2.50320564e+00,   2.77268566e+00,   3.46546416e+00,
#            3.32930620e+00,   1.97028283e+00,   2.96664785e+00,
#            3.11064300e+00,   3.68624680e+00],
#         [ -6.17796846e-02,  -3.37103922e-01,   5.43219071e-01,
#            7.98149671e-01,   5.83029073e-01,   9.54324333e-02,
#            7.05812109e-01,  -5.51252612e-02,   5.18264570e-01,
#            5.22558145e-01,   2.15975025e-01,   5.83445085e-01,
#            5.21805205e-01,   6.87714587e-03,  -1.70314229e-01,
#           -8.48551598e-01,  -8.15611060e-01,  -5.38749539e-01,
#           -1.33535544e-01,  -2.59647314e-01,  -3.56923860e-01,
#           -1.46315671e-01,  -1.26760765e-01],
#         [ -9.00653618e-01,  -2.96446056e-01,  -3.86294190e-01,
#            5.58659312e-02,   4.37538121e-01,  -2.13835903e-01,
#           -5.65402137e-01,  -2.69876629e-01,   5.35319182e-01,
#           -3.01338391e-01,  -1.37560582e+00,  -1.21727844e+00,
#           -6.12052726e-01,  -1.58482386e-01,  -6.95071921e-01,
#           -2.31943571e-01,  -9.15550382e-02,  -9.10893772e-02,
#           -6.48300300e-02,   6.19926371e-01,  -6.59419476e-01,
#           -6.31622798e-01,  -3.26009117e-01],
#         [ -1.10351074e+00,  -6.02682906e-01,  -9.60317140e-01,
#           -8.59012196e-01,  -8.10712974e-02,  -7.61776804e-01,
#           -8.36274093e-01,  -5.27874416e-01,  -1.84559679e-01,
#           -4.72975704e-01,  -8.97208254e-01,  -8.99517226e-01,
#           -7.34659640e-01,  -3.66440674e-01,  -3.42549675e-01,
#           -5.20799034e-02,  -2.33211294e-01,  -6.44889079e-01,
#            9.44902039e-02,  -2.65432600e-01,  -5.97410843e-01,
#           -8.11113770e-01,  -9.87958702e-01],
#         [  7.43997643e-01,   1.34627843e-01,   2.99011130e-01,
#            1.93059647e-01,   4.10921914e-01,   5.82066346e-01,
#            8.11870257e-01,   4.44956492e-01,   6.20656126e-01,
#            4.66268228e-01,   1.02337409e+00,   1.19800048e+00,
#            5.90863816e-01,   2.80570437e-02,   1.35525088e+00,
#            1.08601490e+00,   1.40983915e+00,   1.00960537e+00,
#            7.38068716e-01,   3.60696847e-01,   6.32951109e-01,
#            7.60135062e-01,   1.64942270e-01],
#         [ -9.34856834e-02,   3.30018106e-01,   1.88903182e-01,
#           -8.79397734e-02,   2.40245552e-01,   2.12089633e-01,
#           -1.70255423e-01,   1.89302806e-01,  -6.97453389e-03,
#           -2.51502759e-01,  -4.05447412e-01,  -3.62088935e-01,
#           -9.16474676e-02,  -2.89335270e-02,  -4.47463814e-01,
#            4.36896782e-02,  -1.54137695e-01,   1.32552170e-01,
#            1.77541888e-01,   3.29405959e-01,   3.98292945e-01,
#            4.74001498e-01,  -4.85453701e-02],
#         [ -4.88119861e-04,  -5.58908496e-02,  -2.52877556e-01,
#           -9.51705187e-02,   1.11378762e-01,   3.07007048e-01,
#            6.62880436e-01,   3.26211771e-01,   1.64843981e-01,
#            7.74690192e-03,   4.92123107e-01,   5.20818458e-01,
#            1.20739726e-01,  -4.77873403e-03,  -6.57781154e-01,
#           -2.54052025e-01,  -2.50716906e-01,  -3.01221325e-01,
#           -4.39838332e-01,  -4.67770269e-01,  -1.59754991e-01,
#            5.09448924e-03,  -1.65966977e-01],
#         [ -1.02654527e-01,   3.02519235e-01,   2.00358443e-01,
#            1.11872517e-01,   9.95971210e-02,  -3.01501168e-02,
#            1.36528574e-01,   1.55562161e-01,   7.56922113e-03,
#           -2.68494483e-01,  -4.15552118e-01,  -4.66600653e-01,
#           -1.90419016e-01,  -7.75408955e-02,   2.32955570e-01,
#            1.30853892e-01,   6.10345886e-01,   1.09911662e-01,
#           -4.66209453e-02,   1.68407771e-01,  -3.60566087e-02,
#           -1.58204932e-01,  -2.18016964e-01],
#         [ -4.67028285e-01,  -1.11062261e-01,  -1.70854096e-01,
#           -8.07222966e-02,  -2.14331450e-01,  -5.08727826e-01,
#           -5.04933405e-01,  -2.27982937e-01,  -3.70688267e-02,
#            8.87959911e-02,  -1.62852568e-01,  -4.70026715e-01,
#           -2.50454601e-02,  -1.87718047e-01,  -2.96347504e-01,
#           -2.35768532e-01,  -1.10130068e-01,  -1.50576177e-01,
#            4.02787785e-02,   1.90300525e-01,   9.15526920e-02,
#           -1.58960727e-01,   1.89367340e-02],
#         [ -2.73195169e-01,  -9.55106945e-02,  -3.17631535e-01,
#            2.72395272e-02,   3.03642185e-02,  -7.09004840e-02,
#           -1.09167581e-02,  -3.33450169e-02,  -2.20657989e-01,
#           -1.76821486e-01,   3.74018415e-02,  -3.42064538e-02,
#           -2.20787028e-01,   1.40286587e-01,  -3.92698125e-01,
#           -7.15114138e-02,  -2.87197081e-01,  -2.19310081e-01,
#           -6.75649764e-02,  -1.27887901e-01,  -1.88657449e-01,
#           -3.45850045e-01,  -1.23737188e-02],
#         [ -5.21443298e-02,   1.04343472e-01,   2.60003373e-01,
#            2.69954557e-01,  -3.17818507e-01,  -1.82864434e-01,
#           -3.73348246e-01,  -1.50971097e-01,   4.65119798e-01,
#           -5.62570345e-02,   8.44111720e-02,   2.51782153e-01,
#            4.00942395e-01,   1.28780645e-01,   1.68082211e-01,
#            2.85092658e-01,   3.76069314e-01,   5.29516675e-01,
#            4.33593311e-01,   1.84061228e-01,   3.21413332e-01,
#            1.75970319e-01,   3.71143103e-01],
#         [ -9.94551094e-02,  -1.89316310e-01,  -4.07963204e-01,
#            4.78348415e-02,  -2.23678851e-01,   3.49292756e-01,
#            4.91452429e-01,   3.24877947e-01,   5.20925016e-01,
#            4.83313575e-03,  -3.38005406e-02,   1.16400028e-01,
#            1.19073122e-01,   4.10193096e-01,  -1.88259525e-01,
#            9.08029976e-02,  -1.48353944e-02,   1.02402586e-01,
#            1.55244298e-01,   2.37092435e-01,  -5.89906717e-02,
#           -7.85839614e-02,  -2.31194241e-01],
#         [  2.18417311e-03,   1.41539006e-02,   3.07586346e-02,
#            7.07199812e-03,   1.09400852e-02,   1.02269073e-02,
#            1.06520779e-02,   1.23978938e-02,   4.04933257e-03,
#            2.34032204e-02,   6.95265534e-03,   4.86472946e-03,
#            6.00760143e-03,   4.70180150e-03,   3.81422158e-03,
#            4.76778244e-03,   1.04538082e-02,   7.89054992e-03,
#            5.08819694e-03,   3.39915578e-03,   1.22141573e-02,
#            1.35989038e-02,   6.40319929e-02],
#         [  7.58993686e-03,   3.97741003e-02,   2.29906763e-02,
#            1.52931861e-03,   8.37858897e-04,   2.97741840e-03,
#            3.93092307e-03,   1.33728132e-02,   1.56031480e-04,
#            5.38389663e-03,   2.22961583e-02,   1.47002642e-02,
#            7.80498811e-03,   8.76522654e-03,   3.07492885e-03,
#            9.47922731e-03,   1.32071875e-02,   5.82270727e-03,
#            2.77690453e-03,   3.83168902e-03,   8.46008673e-03,
#            3.79884940e-02,   1.44462987e-02],
#         [  4.55017761e-02,   3.53770317e-03,   7.26793944e-03,
#            3.29463509e-02,   3.87590811e-02,   6.12977322e-02,
#            8.28955305e-02,   4.14803374e-02,   8.06931463e-02,
#            2.61893791e-02,   1.25690339e-02,   1.66522130e-02,
#            5.13495061e-03,   5.26239762e-03,   7.62085564e-03,
#            6.08146319e-03,   4.56959559e-03,   1.01945967e-02,
#            1.21928268e-02,   4.86195185e-03,   1.27138284e-02,
#            1.05637088e-02,   2.25560239e-03],
#         [  2.66320779e-02,   3.13225710e-03,   9.34163551e-03,
#            1.92593748e-02,   3.68050591e-03,   5.26855472e-02,
#            3.80981352e-02,   1.81975473e-02,   1.28574627e-03,
#            2.30141104e-02,   1.39490407e-02,   9.85231307e-03,
#            3.53674073e-03,   3.31376035e-03,   9.84492216e-03,
#            5.27782686e-03,   1.10428405e-03,   5.95217951e-03,
#            3.63631444e-03,   5.42386787e-03,   7.56838716e-03,
#            4.25229748e-03,   2.08805657e-03],
#         [  5.18946893e-03,   3.61656456e-03,   8.48424006e-03,
#            4.58380623e-02,   4.36813991e-02,   9.65568966e-03,
#            5.21775317e-03,   1.15432332e-02,   2.13886582e-02,
#            2.67320097e-02,   8.60467275e-03,   1.67833023e-02,
#            1.12751974e-02,   7.42370016e-03,   8.91108122e-03,
#            4.77911907e-03,   6.13795673e-03,   2.70969564e-02,
#            2.93170122e-02,   1.35741033e-02,   2.29231486e-03,
#            4.08277795e-03,   4.87601721e-03],
#         [  8.82166909e-03,   1.17376830e-02,   9.03375358e-02,
#            3.35796696e-02,   6.08720933e-03,   7.79229154e-03,
#            4.82003620e-03,   3.58658274e-02,   1.95448458e-02,
#            2.24002699e-02,   1.72195244e-02,   6.12250728e-02,
#            1.64559890e-01,   1.38388119e-01,   3.89708255e-02,
#            1.01106112e-02,   3.64472683e-02,   4.97377568e-02,
#            4.10879831e-02,   2.61481204e-02,   4.46525391e-02,
#            1.02988087e-01,   1.09357311e-01],
#         [  3.78921294e-02,   1.10023257e-01,   7.05569989e-02,
#            5.66569107e-02,   2.83402533e-02,   1.41197255e-02,
#            2.05337777e-02,   5.01729190e-02,   7.28689914e-02,
#            4.25688982e-02,   4.64122965e-02,   5.03379241e-02,
#            6.63682491e-02,   9.47228783e-02,   1.20374125e-01,
#            9.79489411e-02,   8.01430486e-02,   9.98083062e-02,
#            1.13495954e-01,   1.08648288e-01,   6.26823421e-02,
#            6.14388172e-02,   5.14947827e-02],
#         [  3.21283482e-03,   1.49394181e-03,   2.36013315e-05,
#            4.48694265e-04,   9.26270284e-04,   3.79242412e-04,
#            2.99864978e-04,   9.64155474e-04,   3.44629697e-04,
#            9.22331090e-04,   2.14422703e-03,   1.67408007e-03,
#            5.12694016e-04,   7.18371222e-04,   7.47795470e-03,
#            8.28980954e-03,   1.51433071e-03,   2.57559020e-04,
#            4.50250640e-04,   3.72520512e-03,   4.28524194e-03,
#            9.16998046e-04,   7.29207225e-04],
#         [  2.24903719e-02,   9.29260051e-03,   1.91129053e-03,
#            5.10750786e-03,   6.82213376e-03,   1.25856126e-02,
#            2.08025611e-02,   1.92273717e-02,   3.45440858e-02,
#            3.99574808e-02,   2.29432765e-02,   1.56022551e-02,
#            3.10900080e-03,   4.94293910e-03,   1.70575097e-03,
#            2.11198638e-03,   2.09154130e-03,   8.41718066e-03,
#            4.93678311e-03,   4.39687033e-03,   1.27099770e-02,
#            1.59624129e-03,   4.21212088e-03],
#         [  2.26471887e-02,   1.52982748e-02,   1.13386296e-02,
#            8.68778661e-03,   1.14766061e-02,   2.98776937e-02,
#            2.83141537e-02,   6.07045530e-03,   5.37498417e-03,
#            1.87430857e-02,   2.59391982e-02,   3.34086598e-03,
#            2.95653375e-03,   3.32029634e-03,   1.70528037e-02,
#            4.31124606e-02,   4.59120961e-02,   5.72437820e-03,
#            2.01503098e-02,   3.32570959e-02,   1.83371126e-02,
#            8.83406023e-03,   5.28343398e-03],
#         [  4.26180838e-03,   2.16232586e-03,   8.10928591e-03,
#            2.02579910e-02,   7.59865400e-03,   1.51308010e-02,
#            1.85252295e-02,   2.56342474e-02,   2.87343899e-02,
#            1.20333058e-02,   3.38578027e-03,   4.64739097e-03,
#            5.75946144e-03,   2.66207555e-03,   6.52874118e-03,
#            4.18819454e-03,   4.71871345e-03,   6.36263977e-03,
#            7.18596131e-03,   1.18114079e-02,   7.70745275e-03,
#            5.54678893e-03,   3.21575052e-03],
#         [  1.69885042e-03,   3.31578135e-03,   2.89214931e-03,
#            8.00562472e-03,   1.84643716e-03,   4.61627056e-04,
#            3.78050840e-04,   8.83816001e-04,   4.37294837e-04,
#            2.81702390e-03,   5.21704935e-03,   5.56969471e-03,
#            1.34426082e-03,   1.39469357e-03,   2.57000014e-04,
#            4.34631348e-04,   1.06469472e-03,   3.87329714e-03,
#            2.07009548e-03,   2.65591308e-03,   1.59752246e-03,
#            3.91660968e-03,   1.60993590e-03],
#         [  1.43861625e-02,   2.95173967e-02,   2.77243645e-02,
#            1.76732010e-02,   1.43316673e-02,   1.90380237e-02,
#            2.22124785e-02,   1.51457227e-02,   2.68916957e-02,
#            1.27611313e-02,   1.20115929e-02,   1.82062334e-02,
#            4.59564083e-02,   4.28476576e-02,   3.21673426e-02,
#            2.68106119e-02,   2.35397706e-02,   2.75566251e-02,
#            3.05710151e-02,   2.87813301e-02,   1.77248382e-02,
#            3.00467067e-02,   3.31931653e-02]]),
#  array([[  1.08892922e-02,   1.22504537e-02,   1.81488203e-02, ...,
#            2.08711434e-02,   1.81488203e-02,   1.36116152e-02],
#         [  2.16603597e-02,   4.14591829e-02,   5.06074935e-02, ...,
#            2.02339796e-03,   1.21397271e-03,   1.66331080e-03],
#         [  3.11928067e+00,   3.25673608e+00,   3.27541711e+00, ...,
#            3.16481282e+00,   3.11931203e+00,   3.02803199e+00],
#         ...,
#         [  4.71295833e-03,   4.00762656e-03,   1.52338387e-03, ...,
#            1.38966945e-02,   2.18876077e-02,   8.58143787e-03],
#         [  2.21068588e-04,   6.37188500e-04,   8.20339218e-04, ...,
#            6.94573168e-03,   1.64635041e-03,   2.99787223e-03],
#         [  4.97393925e-02,   4.02012832e-02,   4.63611837e-02, ...,
#            2.93824013e-02,   3.15681502e-02,   4.74146350e-02]]),
#  array([[  5.63204005e-02,   1.18898623e-01,   1.46433041e-01, ...,
#            4.63078849e-02,   6.88360451e-02,   8.13516896e-02],
#         [  1.30342161e-02,   2.20253108e-02,   2.27791287e-02, ...,
#            3.17342872e-03,   6.36089429e-03,   6.83451449e-03],
#         [  2.89918444e+00,   3.29947866e+00,   3.30395733e+00, ...,
#            2.99496771e+00,   3.04344612e+00,   3.20222041e+00],
#         ...,
#         [  3.74944163e-03,   1.51058893e-03,   2.06500451e-03, ...,
#            1.19098368e-03,   1.80746869e-03,   3.03099106e-04],
#         [  3.89304656e-04,   1.08899472e-03,   2.44698671e-04, ...,
#            2.44293215e-03,   3.84434733e-04,   1.58930426e-04],
#         [  3.52484249e-02,   4.07195728e-02,   3.88344375e-02, ...,
#            2.55942865e-02,   4.44805958e-02,   2.15960861e-02]]),
#  array([[  7.63454318e-02,   1.06382979e-01,   6.75844806e-02, ...,
#            4.75594493e-02,   6.50813517e-02,   5.50688360e-02],
#         [  7.99903749e-02,   1.24540591e-01,   9.02977641e-02, ...,
#            1.75899258e-02,   3.21079508e-02,   3.14230184e-02],
#         [  3.08808005e+00,   3.26016018e+00,   3.11238105e+00, ...,
#            3.12371417e+00,   3.21601232e+00,   3.22444250e+00],
#         ...,
#         [  9.32491533e-03,   1.84070953e-02,   4.29109375e-02, ...,
#            1.09098835e-02,   1.80533501e-03,   3.10211015e-03],
#         [  9.97279650e-04,   1.10708395e-03,   3.34781103e-04, ...,
#            8.47209426e-03,   1.57369935e-03,   6.29782939e-04],
#         [  2.85505154e-02,   2.07090608e-02,   3.41789979e-02, ...,
#            3.17835365e-02,   2.60815650e-02,   3.43784103e-02]]),
#  array([[  7.50938673e-02,   6.13266583e-02,   5.75719650e-02,
#            5.63204005e-02,   4.50563204e-02,   3.62953692e-02,
#            3.50438048e-02,   5.63204005e-02,   7.63454318e-02,
#            7.63454318e-02,   8.01001252e-02],
#         [  1.26082675e-01,   1.06595505e-01,   5.53393994e-02,
#            4.13487159e-02,   4.74374890e-02,   5.29653082e-02,
#            4.46274834e-02,   7.12370729e-02,   1.49818910e-01,
#            1.61335906e-01,   1.10950911e-01],
#         [  3.27376298e+00,   3.20440214e+00,   3.14947862e+00,
#            3.26171370e+00,   3.29254554e+00,   3.30215938e+00,
#            3.21013374e+00,   2.79977478e+00,   3.14838643e+00,
#            3.29877949e+00,   3.26726496e+00],
#         [  1.63746539e-01,   1.58739026e-01,   1.62121950e-01,
#            1.70480559e-01,   1.56428689e-01,   1.70403394e-01,
#            1.30548389e-01,   1.80622814e-01,   1.85930037e-01,
#            1.95577923e-01,   1.44815607e-01],
#         [  1.72776843e-01,   1.77631110e-01,   1.71075677e-01,
#            2.10520734e-01,   1.98428526e-01,   2.25547041e-01,
#            1.90131450e-01,   1.99536069e-01,   1.95637887e-01,
#            2.09936404e-01,   1.70515082e-01],
#         [  8.07210626e-01,   1.00675013e+00,   7.42588986e-01,
#            2.23408881e-01,   1.30085324e-01,   1.44359557e-01,
#            5.00342900e-02,   5.52277664e-01,   4.97451498e-01,
#            5.69091800e-01,   5.64985338e-01],
#         [  0.00000000e+00,   1.12644346e-02,   9.86497120e-03,
#            2.93056711e-02,   1.99677445e-02,   9.78812435e-03,
#            5.16771833e-02,   6.38024398e-02,   1.27771376e-02,
#            2.79998292e-03,   3.46169033e-03],
#         [  1.00000000e-01,   1.02500000e-01,   1.02500000e-01,
#            7.25000000e-02,   7.25000000e-02,   4.00000000e-02,
#            3.75000000e-02,   8.25000000e-02,   7.75000000e-02,
#            8.75000000e-02,   1.15000000e-01],
#         [ -2.24635623e+01,  -2.20852839e+01,  -2.33983130e+01,
#           -2.40321509e+01,  -2.53739875e+01,  -2.39802756e+01,
#           -2.65584449e+01,  -2.16458429e+01,  -2.20613633e+01,
#           -2.15723333e+01,  -2.33119708e+01],
#         [  1.78706366e+00,   2.20306959e+00,   1.97768666e+00,
#            2.65808851e+00,   2.66424254e+00,   2.73916884e+00,
#            3.12614125e+00,   2.10406629e+00,   1.97404175e+00,
#            1.60705240e+00,   2.89213839e+00],
#         [ -1.17657474e+00,  -4.13743762e-01,  -5.47260853e-01,
#            1.95479231e-01,  -3.49723903e-02,   1.50342570e-01,
#            5.00738132e-01,  -3.88196494e-01,  -4.54139213e-01,
#           -1.00474174e+00,  -1.25329510e+00],
#         [ -7.27100294e-01,   5.56954331e-01,  -6.14523692e-02,
#           -7.12349480e-01,  -1.33976250e+00,  -3.51031725e-01,
#           -9.10109142e-01,  -3.35404080e-01,  -8.78295952e-01,
#           -4.57783993e-01,  -1.24794263e+00],
#         [ -7.17526466e-01,  -1.79162753e-01,  -1.54917550e-02,
#           -1.03961457e-01,  -1.84859232e-01,   3.50129975e-02,
#           -1.34953989e-01,  -3.06728977e-01,  -5.79075018e-01,
#            7.47495354e-02,  -5.33695929e-01],
#         [  2.55109438e-01,   2.95206493e-01,   2.63555712e-01,
#           -2.97566310e-01,  -3.03204688e-01,  -3.63037946e-01,
#           -6.23175156e-01,  -1.52525441e-01,  -2.63654732e-01,
#           -1.28866245e-01,  -6.55802832e-01],
#         [ -1.14844320e+00,  -8.88593009e-01,  -1.04055285e+00,
#           -5.14420874e-01,  -4.22138161e-01,  -5.47737570e-01,
#           -6.37629747e-01,  -4.67715702e-01,  -1.42024189e-01,
#           -1.75972341e-01,   1.32931445e-01],
#         [ -4.17481706e-01,  -7.96418794e-02,  -4.57931768e-01,
#           -2.98584108e-01,  -6.73073185e-01,  -8.42753780e-01,
#           -7.50677047e-01,  -8.63292465e-01,  -9.40552703e-01,
#           -1.25212308e+00,  -9.99082240e-01],
#         [ -2.47357075e-01,  -4.48746198e-01,  -5.13191625e-01,
#           -6.11584765e-01,  -9.03485320e-01,  -5.79218473e-01,
#           -7.73754312e-01,  -4.69676565e-01,  -4.83858776e-01,
#           -6.88024990e-01,  -5.64635688e-01],
#         [ -1.12509634e+00,  -1.08317557e+00,  -9.26187387e-01,
#           -6.51066337e-01,  -4.57760826e-01,  -1.06938995e-01,
#           -4.78026611e-01,  -4.14981991e-01,  -5.19754094e-01,
#           -1.32800809e-01,  -4.13907022e-01],
#         [ -4.77931767e-01,  -3.65578911e-01,  -7.19150233e-02,
#            3.87194737e-01,   2.88945682e-01,   3.17127094e-01,
#            3.65509996e-01,   5.97579086e-01,   6.96778498e-01,
#            5.65827431e-01,   7.00889189e-01],
#         [ -1.33346314e-01,   2.99295478e-02,   3.37420282e-01,
#            6.49406635e-01,   3.00100070e-01,   4.26209256e-01,
#            5.69880652e-01,   2.16652446e-01,   3.99209540e-01,
#            5.85509506e-01,   5.50498499e-01],
#         [  6.84152739e-01,   9.01209288e-01,   6.33520904e-01,
#            2.72977781e-01,   5.04556292e-01,   1.83106682e-01,
#            6.51135975e-01,   1.80019531e-01,   5.49902058e-01,
#            3.93506466e-01,   3.50189849e-01],
#         [  6.12527597e-04,   2.27075419e-03,   9.96076943e-04,
#            2.56366842e-03,   5.88867277e-04,   1.48993560e-03,
#            2.76071053e-04,   2.71024180e-03,   4.22841246e-04,
#            6.71767159e-04,   5.95583281e-04],
#         [  1.76412793e-03,   1.59274902e-03,   5.81597258e-04,
#            2.86350880e-04,   2.01311120e-04,   3.91405882e-04,
#            7.75572253e-05,   2.88236977e-03,   3.16884121e-03,
#            5.39135659e-03,   8.83421718e-03],
#         [  1.36286449e-03,   6.03306573e-03,   1.82170545e-03,
#            3.21302746e-03,   4.86143926e-04,   3.31527851e-03,
#            3.44483943e-04,   4.31715833e-03,   1.46005438e-03,
#            7.88036577e-04,   1.42393223e-03],
#         [  6.23260055e-03,   1.21388404e-02,   2.76009007e-03,
#            3.14064452e-03,   8.90105328e-04,   2.96732538e-03,
#            2.65486850e-04,   1.98409776e-03,   2.25950026e-03,
#            1.29298053e-03,   1.46651121e-03],
#         [  1.84687220e-01,   1.06280696e-01,   2.98397145e-02,
#            3.65946853e-03,   6.09812167e-03,   1.66940819e-02,
#            6.12345528e-03,   4.91814447e-02,   4.17670891e-03,
#            2.10443349e-03,   2.75286791e-03],
#         [  9.38119069e-03,   8.96461411e-02,   2.01568650e-01,
#            1.02568331e-01,   7.81296362e-03,   2.98223058e-02,
#            2.59009455e-01,   5.35974327e-02,   1.93194739e-03,
#            9.33266945e-03,   1.75145008e-02],
#         [  2.83040754e-03,   8.68436444e-03,   3.64761596e-03,
#            1.34251063e-01,   2.09025553e-01,   1.85153109e-01,
#            4.32173467e-02,   4.89711981e-02,   1.42313593e-01,
#            1.70402872e-01,   1.54043953e-01],
#         [  2.62002331e-04,   1.32203515e-04,   1.64497303e-04,
#            3.07859886e-04,   7.80397870e-04,   6.99408242e-04,
#            7.70932716e-05,   1.05144268e-02,   9.70452687e-04,
#            8.47225285e-03,   4.97233745e-03],
#         [  7.63856523e-04,   1.24179341e-03,   1.88282356e-03,
#            6.64935942e-03,   1.72830600e-03,   7.30621994e-03,
#            3.68408114e-03,   4.68899134e-02,   2.16139211e-02,
#            1.30405386e-02,   1.86813553e-02],
#         [  8.00099231e-04,   1.22969622e-03,   7.69328524e-04,
#            1.75779599e-03,   6.89070697e-04,   1.57494056e-03,
#            4.08257561e-04,   1.81229064e-03,   3.12749914e-03,
#            2.03162799e-03,   1.38491676e-03],
#         [  1.58450434e-02,   4.83997698e-03,   2.14180747e-03,
#            2.30809767e-03,   1.38635910e-03,   1.91680861e-03,
#            1.02482623e-03,   5.04773446e-03,   7.68629257e-04,
#            9.13924239e-04,   1.29162260e-03],
#         [  5.15580963e-03,   3.32901140e-02,   1.40823334e-02,
#            1.00569238e-03,   5.00226973e-04,   1.09489738e-03,
#            3.52223727e-04,   2.41793221e-03,   1.22148565e-04,
#            5.85837562e-04,   7.65055691e-04],
#         [  5.01096819e-02,   3.50902607e-02,   5.48547494e-02,
#            4.37129316e-02,   5.72873237e-02,   5.01856830e-02,
#            7.11482636e-02,   2.17003936e-02,   3.87295590e-02,
#            4.61469756e-02,   4.15308554e-02]]),
#  array([[  1.35168961e-01,   1.20150188e-01,   1.02628285e-01, ...,
#            5.13141427e-02,   4.63078849e-02,   4.50563204e-02],
#         [  1.44573677e-03,   3.48165139e-03,   5.16843887e-03, ...,
#            3.78921505e-03,   3.66123545e-03,   3.45635386e-03],
#         [  3.22990750e+00,   2.88916575e+00,   3.17994907e+00, ...,
#            3.24188600e+00,   3.24763264e+00,   3.28088670e+00],
#         ...,
#         [  4.87180504e-03,   2.77185516e-02,   4.04958516e-02, ...,
#            1.02053370e-01,   4.43751879e-02,   1.79420150e-02],
#         [  8.10417584e-04,   6.29636020e-03,   8.72950269e-03, ...,
#            2.93577635e-02,   3.38815498e-02,   4.12942838e-04],
#         [  1.08288516e-02,   9.37707388e-03,   1.09359052e-02, ...,
#            2.72667255e-02,   1.40611887e-02,   2.56735445e-02]]),
#  array([[  6.38297872e-02,   7.88485607e-02,   7.50938673e-02, ...,
#            6.13266583e-02,   4.88110138e-02,   3.62953692e-02],
#         [  4.09794282e-02,   9.42069938e-02,   1.25379656e-01, ...,
#            2.48569229e-03,   2.65540147e-03,   2.98339378e-03],
#         [  2.68934406e+00,   3.13903135e+00,   3.22869181e+00, ...,
#            2.94679169e+00,   3.07847449e+00,   3.07495079e+00],
#         ...,
#         [  9.40377775e-03,   3.06072560e-03,   1.99124770e-03, ...,
#            2.88217461e-03,   4.88910553e-03,   2.27363570e-03],
#         [  1.81733653e-02,   8.66589050e-03,   9.47655248e-03, ...,
#            9.68980666e-04,   2.49966022e-04,   5.24957171e-04],
#         [  2.41875337e-02,   1.53864913e-02,   4.33264740e-02, ...,
#            2.45374140e-02,   3.02256540e-02,   4.40093530e-02]]),
#  array([[  1.40653358e-02,   9.07441016e-03,   9.52813067e-03, ...,
#            2.04174229e-02,   2.04174229e-02,   1.95099819e-02],
#         [  1.50394610e-02,   1.73720993e-02,   1.95591038e-02, ...,
#            7.94696307e-03,   1.01547314e-02,   1.07327354e-02],
#         [  3.25552786e+00,   3.26182586e+00,   3.30933143e+00, ...,
#            3.20524846e+00,   3.24674578e+00,   3.26736784e+00],
#         ...,
#         [  1.50223945e-01,   1.58729738e-01,   1.64160795e-01, ...,
#            1.14102318e-02,   2.53808888e-03,   1.98023976e-03],
#         [  2.04965624e-03,   1.00625205e-03,   3.27146417e-04, ...,
#            4.00497296e-04,   8.34892197e-04,   4.10885174e-04],
#         [  4.01491710e-02,   4.30490616e-02,   4.47782623e-02, ...,
#            2.68244227e-02,   4.81263583e-02,   4.78759655e-02]]),
#  array([[  6.25782228e-02,   5.75719650e-02,   4.38047559e-02, ...,
#            5.75719650e-02,   5.13141427e-02,   5.63204005e-02],
#         [  7.59019127e-02,   6.58250034e-02,   5.94750610e-02, ...,
#            6.82257220e-03,   3.41308408e-03,   2.16986695e-03],
#         [  3.20729226e+00,   3.10521840e+00,   3.01743741e+00, ...,
#            3.11206268e+00,   2.91737128e+00,   3.11273296e+00],
#         ...,
#         [  1.62851006e-02,   4.88001270e-02,   7.69405938e-02, ...,
#            1.70004608e-02,   4.34316261e-02,   1.98400888e-02],
#         [  2.53653516e-03,   1.81569299e-04,   2.07513757e-02, ...,
#            1.45404645e-02,   1.98275263e-02,   1.59990959e-02],
#         [  1.11709808e-02,   1.62663704e-02,   2.06832088e-02, ...,
#            1.15709141e-02,   1.58061344e-02,   2.04620940e-02]]),
#  array([[  4.75594493e-02,   4.88110138e-02,   5.50688360e-02, ...,
#            6.00750939e-02,   5.00625782e-02,   5.00625782e-02],
#         [  2.95375653e-03,   5.91056853e-03,   2.58225838e-02, ...,
#            3.53779868e-03,   6.07664924e-03,   1.16664195e-02],
#         [  3.13564648e+00,   3.15920250e+00,   2.48529579e+00, ...,
#            3.20980111e+00,   3.00787414e+00,   3.10629981e+00],
#         ...,
#         [  4.42447180e-03,   4.03019392e-03,   1.62705496e-02, ...,
#            2.23326069e-02,   1.32760515e-02,   4.73238652e-02],
#         [  1.25895110e-03,   9.54849222e-04,   2.89884454e-03, ...,
#            2.67029818e-02,   1.38016127e-02,   4.42027089e-02],
#         [  3.40391810e-02,   2.67464328e-02,   2.18305912e-02, ...,
#            1.08978369e-02,   1.53804072e-02,   1.61855539e-02]]),
#  array([[  9.13642053e-02,   9.13642053e-02,   9.26157697e-02, ...,
#            6.13266583e-02,   8.63579474e-02,   1.07634543e-01],
#         [  2.57149109e-02,   5.39548540e-02,   5.98668245e-02, ...,
#            5.59794682e-03,   4.78972914e-03,   2.62362820e-03],
#         [  3.12133067e+00,   3.14690248e+00,   3.18367703e+00, ...,
#            3.20584134e+00,   3.06900653e+00,   3.09801046e+00],
#         ...,
#         [  9.29916861e-03,   7.08378481e-02,   3.33263742e-02, ...,
#            3.17229193e-02,   1.88741984e-02,   4.17430398e-02],
#         [  1.15438356e-02,   2.52759435e-02,   6.82768384e-03, ...,
#            3.53193688e-03,   2.26618279e-03,   1.39226824e-03],
#         [  1.07573062e-02,   1.94302881e-02,   1.98853380e-02, ...,
#            3.49266845e-02,   3.06995835e-02,   1.73012900e-02]]),
#  array([[  1.07634543e-01,   1.25156446e-01,   1.36420526e-01, ...,
#            5.63204005e-02,   5.75719650e-02,   6.38297872e-02],
#         [  1.23090062e-02,   2.82799557e-02,   3.84513684e-02, ...,
#            6.77703899e-03,   5.58640835e-03,   3.36211954e-03],
#         [  3.05826821e+00,   3.13477141e+00,   3.25425037e+00, ...,
#            3.24421563e+00,   3.10506122e+00,   3.09847613e+00],
#         ...,
#         [  2.29538246e-02,   6.64869884e-03,   1.83622942e-03, ...,
#            8.88240687e-03,   2.53135275e-02,   1.30713648e-02],
#         [  7.39255884e-03,   3.60130254e-03,   1.19245789e-03, ...,
#            3.35535156e-02,   1.78286546e-02,   4.98036879e-03],
#         [  1.16626355e-02,   1.39409989e-02,   2.48177536e-02, ...,
#            1.19901489e-02,   1.54603042e-02,   1.61273742e-02]]),
#  array([[  2.35934664e-02,   2.26860254e-02,   2.40471869e-02, ...,
#            1.81488203e-02,   1.95099819e-02,   2.67695100e-02],
#         [  1.89331600e-02,   1.65267301e-02,   2.05916075e-02, ...,
#            1.54311188e-02,   1.32508580e-02,   1.15734682e-02],
#         [  3.16631191e+00,   3.02206989e+00,   2.92438739e+00, ...,
#            3.20641885e+00,   3.15778654e+00,   3.15913582e+00],
#         ...,
#         [  2.19503469e-02,   5.62558573e-02,   6.97603266e-03, ...,
#            2.63356966e-03,   6.33994694e-03,   7.61507183e-03],
#         [  1.25998153e-03,   5.51849095e-03,   9.60473400e-03, ...,
#            4.90497529e-05,   2.61879160e-03,   7.13770601e-04],
#         [  1.17490928e-02,   2.04508127e-02,   2.64968499e-02, ...,
#            3.43468521e-02,   2.19754674e-02,   1.51736062e-02]]),
#  array([[  1.54264973e-02,   2.08711434e-02,   1.81488203e-02, ...,
#            1.08892922e-02,   1.08892922e-02,   9.52813067e-03],
#         [  1.76852457e-02,   2.22074530e-02,   1.00483329e-02, ...,
#            5.38781928e-03,   3.71841066e-03,   2.70868209e-03],
#         [  3.10953130e+00,   3.09476440e+00,   2.16103405e+00, ...,
#            3.19747730e+00,   3.20916023e+00,   3.20145951e+00],
#         ...,
#         [  3.24766883e-03,   6.88710814e-04,   4.47224845e-03, ...,
#            3.14585261e-03,   2.51260362e-03,   2.16756374e-03],
#         [  3.11978334e-03,   2.84519097e-03,   1.49935430e-04, ...,
#            1.71293769e-04,   1.32257492e-03,   3.71404766e-04],
#         [  3.23171356e-02,   1.83415969e-02,   2.39922223e-02, ...,
#            3.98592889e-02,   4.21035459e-02,   4.04309351e-02]]),
#  array([[  2.26860254e-02,   1.99637024e-02,   2.17785844e-02, ...,
#            2.35934664e-02,   2.13248639e-02,   1.72413793e-02],
#         [  8.12245811e-03,   8.37604701e-03,   7.72336387e-03, ...,
#            6.34122328e-04,   1.32490020e-03,   9.14578230e-03],
#         [  3.26665494e+00,   3.26011336e+00,   3.20532030e+00, ...,
#            2.38244473e+00,   2.24051002e+00,   2.68408339e+00],
#         ...,
#         [  5.07972670e-03,   4.16828633e-04,   5.19127460e-03, ...,
#            4.49277617e-02,   2.27240173e-02,   8.83427840e-02],
#         [  2.92320955e-04,   3.38998905e-04,   1.35992888e-03, ...,
#            1.73076021e-02,   1.25427363e-02,   1.21253807e-02],
#         [  1.80922530e-02,   3.31235879e-02,   3.20310805e-02, ...,
#            2.29762015e-02,   1.28145254e-02,   2.85144610e-02]]),
#  array([[  1.90562613e-02,   2.04174229e-02,   1.81488203e-02, ...,
#            2.90381125e-02,   2.45009074e-02,   1.81488203e-02],
#         [  6.83257907e-03,   1.85600120e-03,   3.95046389e-04, ...,
#            8.65474021e-03,   7.37967841e-03,   6.75783123e-03],
#         [  3.01896041e+00,   2.43225231e+00,   3.26940162e+00, ...,
#            3.23362510e+00,   3.25453512e+00,   3.22996515e+00],
#         ...,
#         [  4.84118486e-03,   1.39479397e-02,   1.32435919e-02, ...,
#            9.16155673e-03,   4.93350448e-03,   5.88408448e-03],
#         [  7.28523980e-03,   2.24800778e-03,   8.88831147e-04, ...,
#            8.05016696e-02,   3.24392051e-02,   1.23403601e-02],
#         [  2.21766261e-02,   2.26800547e-02,   3.88298492e-02, ...,
#            2.50268980e-02,   3.45674288e-02,   3.86828817e-02]]),
#  array([[  1.01376721e-01,   9.26157697e-02,   8.76095119e-02, ...,
#            2.87859825e-02,   3.00375469e-02,   3.00375469e-02],
#         [  2.08840008e-02,   3.17619219e-02,   3.54110751e-02, ...,
#            2.87989794e-02,   1.82341232e-02,   1.07017411e-02],
#         [  3.18072582e+00,   3.29847452e+00,   3.31201874e+00, ...,
#            3.26981005e+00,   3.25695050e+00,   3.17985901e+00],
#         ...,
#         [  6.03205905e-03,   3.39521485e-04,   9.09995280e-04, ...,
#            3.07850089e-03,   2.97127416e-03,   2.46286818e-03],
#         [  5.70337965e-04,   5.43097002e-04,   6.23215388e-04, ...,
#            6.52696131e-04,   9.40415712e-04,   2.70997128e-04],
#         [  2.14574121e-02,   3.73822551e-02,   3.59287906e-02, ...,
#            4.75350264e-02,   5.27175117e-02,   6.53214755e-02]]),
#  array([[  7.50938673e-02,   1.28911139e-01,   1.57697121e-01, ...,
#            5.25657071e-02,   5.63204005e-02,   4.63078849e-02],
#         [  1.66804920e-02,   2.96469077e-02,   3.89690121e-02, ...,
#            5.11303597e-03,   2.70328675e-03,   1.68551300e-03],
#         [  2.74296484e+00,   3.19599379e+00,   3.16290424e+00, ...,
#            2.96819332e+00,   2.79596422e+00,   3.08863452e+00],
#         ...,
#         [  9.34696028e-04,   2.14516814e-03,   7.62896539e-04, ...,
#            7.57326981e-04,   2.67284219e-02,   1.85395074e-02],
#         [  4.64896742e-02,   3.77158450e-02,   1.06670301e-02, ...,
#            1.79118296e-02,   6.61952050e-03,   8.86060078e-03],
#         [  1.74502266e-02,   1.04618557e-02,   5.79352441e-03, ...,
#            1.71139257e-02,   9.93557997e-03,   3.74448145e-02]]),
#  array([[  1.04355717e-02,   1.63339383e-02,   1.49727768e-02, ...,
#            1.31578947e-02,   1.58802178e-02,   1.95099819e-02],
#         [  4.23725785e-02,   8.17755833e-02,   9.41688472e-02, ...,
#            3.12548073e-03,   3.44918317e-03,   3.86476227e-03],
#         [  3.10219045e+00,   3.20738218e+00,   3.30728374e+00, ...,
#            3.31143032e+00,   3.09718395e+00,   3.01137515e+00],
#         ...,
#         [  4.84872549e-02,   3.50082667e-02,   4.63926963e-02, ...,
#            9.95731032e-02,   1.92687716e-02,   2.84656638e-02],
#         [  2.66327317e-02,   2.76055390e-02,   1.47597965e-02, ...,
#            2.94199636e-04,   2.12758302e-03,   1.21821895e-03],
#         [  4.21513458e-02,   4.01086431e-02,   4.90797832e-02, ...,
#            2.95430546e-02,   3.06254763e-02,   4.08072425e-02]]),
#  array([[  2.67695100e-02,   2.22323049e-02,   2.63157895e-02, ...,
#            2.81306715e-02,   2.17785844e-02,   2.99455535e-02],
#         [  1.47649822e-02,   2.92328459e-02,   4.31126531e-02, ...,
#            3.28735556e-03,   2.62380292e-03,   5.29403554e-03],
#         [  3.14380628e+00,   3.19731544e+00,   3.27290613e+00, ...,
#            3.14539554e+00,   3.21999767e+00,   2.85451847e+00],
#         ...,
#         [  1.08153233e-02,   8.10179666e-03,   5.29549695e-03, ...,
#            2.67716432e-03,   2.78815481e-03,   2.27427059e-03],
#         [  2.00358710e-02,   5.72413505e-02,   4.84692690e-02, ...,
#            2.42008096e-03,   1.61685692e-03,   2.04119187e-03],
#         [  1.23988194e-02,   1.75420927e-02,   1.71588401e-02, ...,
#            2.98234601e-02,   4.17015199e-02,   2.68345926e-02]]),
#  array([[  1.81488203e-02,   1.31578947e-02,   2.04174229e-02, ...,
#            2.04174229e-02,   2.13248639e-02,   1.81488203e-02],
#         [  1.54457760e-02,   1.33451938e-02,   3.10264514e-02, ...,
#            4.33732764e-03,   7.68370591e-03,   7.61538960e-03],
#         [  3.26549040e+00,   3.27332166e+00,   3.03769107e+00, ...,
#            2.80260865e+00,   3.27755092e+00,   3.24855525e+00],
#         ...,
#         [  9.55696771e-02,   1.33220183e-01,   5.98151886e-02, ...,
#            1.50501920e-02,   4.56970799e-03,   3.48297451e-03],
#         [  1.64732886e-04,   7.31998502e-04,   3.82005824e-04, ...,
#            1.79142162e-02,   3.10302420e-02,   1.81088937e-02],
#         [  2.52757656e-02,   3.64705783e-02,   1.84416688e-02, ...,
#            1.34675469e-02,   2.38714244e-02,   2.02945318e-02]]),
#  array([[  9.52813067e-03,   9.52813067e-03,   1.36116152e-02, ...,
#            2.26860254e-02,   2.40471869e-02,   2.17785844e-02],
#         [  1.07135948e-02,   1.43056018e-02,   4.08550774e-02, ...,
#            1.40639996e-02,   8.18729347e-03,   8.84127518e-03],
#         [  3.23844089e+00,   3.30609385e+00,   2.61832144e+00, ...,
#            3.14438548e+00,   3.20301312e+00,   3.22163240e+00],
#         ...,
#         [  1.05764446e-02,   1.50425453e-02,   4.05651952e-03, ...,
#            4.09861416e-02,   1.31798453e-02,   6.94682603e-03],
#         [  7.97888672e-04,   1.97619244e-03,   3.28016346e-04, ...,
#            8.61222399e-03,   1.49580520e-02,   4.61885404e-03],
#         [  6.64129625e-02,   5.46757828e-02,   3.34568747e-02, ...,
#            1.32209788e-02,   2.07272175e-02,   2.30290980e-02]]),
#  array([[  1.32665832e-01,   8.01001252e-02,   6.88360451e-02, ...,
#            7.00876095e-02,   6.38297872e-02,   6.25782228e-02],
#         [  1.84778256e-02,   3.12332800e-02,   2.59516294e-02, ...,
#            2.05232033e-03,   5.15010092e-03,   5.36034396e-03],
#         [  2.29141993e+00,   3.04324559e+00,   3.13867928e+00, ...,
#            1.96613959e+00,   2.88802365e+00,   3.16776994e+00],
#         ...,
#         [  3.23520833e-02,   1.15852304e-02,   1.24185293e-02, ...,
#            6.45363151e-03,   2.90812403e-03,   1.81813930e-02],
#         [  1.26012982e-02,   2.99317202e-03,   1.07665090e-02, ...,
#            3.10026820e-03,   1.71549905e-04,   2.95670109e-04],
#         [  1.55221889e-02,   2.00477744e-02,   1.86763938e-02, ...,
#            1.68948384e-02,   2.28611463e-02,   2.57141776e-02]]),
#  array([[  2.67695100e-02,   2.45009074e-02,   2.49546279e-02, ...,
#            1.72413793e-02,   1.45190563e-02,   1.49727768e-02],
#         [  1.04283022e-02,   8.62181792e-03,   6.17633930e-03, ...,
#            6.58494479e-03,   2.58500401e-03,   2.71544631e-03],
#         [  3.26997586e+00,   3.12371094e+00,   3.12883323e+00, ...,
#            3.15014831e+00,   3.17033017e+00,   2.98827263e+00],
#         ...,
#         [  3.90883827e-02,   1.61211744e-02,   3.55642387e-02, ...,
#            2.06781329e-02,   1.52342415e-02,   2.21699978e-02],
#         [  1.04326175e-02,   8.24359780e-03,   1.50155109e-02, ...,
#            6.81578662e-03,   1.53405517e-03,   2.16420362e-03],
#         [  1.21222551e-02,   2.07690526e-02,   3.30680144e-02, ...,
#            2.90110646e-02,   3.76252446e-02,   3.13419479e-02]]),
#  array([[  2.76769510e-02,   2.35934664e-02,   1.86025408e-02, ...,
#            1.40653358e-02,   1.31578947e-02,   1.76950998e-02],
#         [  3.47578127e-02,   3.29953398e-02,   2.34542191e-02, ...,
#            1.59079113e-02,   1.74534083e-02,   1.73101929e-02],
#         [  3.19923235e+00,   3.18732235e+00,   3.23040890e+00, ...,
#            3.22000055e+00,   3.05953939e+00,   3.08577933e+00],
#         ...,
#         [  2.39673255e-03,   2.72441407e-03,   2.12933553e-03, ...,
#            9.58435272e-03,   3.09423034e-02,   1.08368656e-02],
#         [  3.18948481e-04,   2.31359004e-03,   8.21469692e-05, ...,
#            1.93014972e-03,   8.76162839e-03,   4.90266849e-03],
#         [  4.74841736e-02,   3.70914576e-02,   3.01226241e-02, ...,
#            3.50096344e-02,   2.19731576e-02,   3.03594507e-02]]),
#  array([[  6.50813517e-02,   6.75844806e-02,   4.38047559e-02, ...,
#            6.88360451e-02,   7.88485607e-02,   7.00876095e-02],
#         [  2.97727520e-02,   3.74920591e-02,   2.16601614e-02, ...,
#            1.11422247e-02,   7.84798892e-03,   9.05776575e-03],
#         [  3.16386661e+00,   3.27374387e+00,   2.91436796e+00, ...,
#            3.22942623e+00,   3.30365067e+00,   3.26805518e+00],
#         ...,
#         [  3.60803510e-02,   5.29658843e-02,   1.15912564e-02, ...,
#            1.28506466e-03,   3.78722217e-03,   1.42105592e-03],
#         [  4.95521291e-04,   1.17653404e-03,   1.43466182e-03, ...,
#            2.44345610e-03,   9.17536289e-04,   1.68903875e-03],
#         [  5.23715627e-02,   5.25990301e-02,   4.54741260e-02, ...,
#            4.53689531e-02,   2.63110910e-02,   4.36220726e-02]]),
#  array([[  5.88235294e-02,   6.50813517e-02,   6.75844806e-02, ...,
#            4.25531915e-02,   4.88110138e-02,   4.38047559e-02],
#         [  6.95417060e-02,   1.43863105e-01,   1.55799020e-01, ...,
#            4.16476449e-03,   7.84712826e-03,   6.94796688e-03],
#         [  2.87333700e+00,   3.14381977e+00,   3.16944761e+00, ...,
#            3.14464008e+00,   3.20875725e+00,   3.02614541e+00],
#         ...,
#         [  5.64969477e-03,   2.52551969e-03,   1.04817032e-03, ...,
#            2.50794460e-02,   1.02800845e-01,   1.13843144e-01],
#         [  1.72262091e-03,   6.09123454e-03,   1.02150708e-02, ...,
#            6.85280603e-02,   7.16471501e-02,   5.59952181e-02],
#         [  2.14228773e-02,   2.56735313e-02,   3.65376030e-02, ...,
#            4.15314048e-02,   3.38417464e-02,   3.13183960e-02]]),
#  array([[  2.08711434e-02,   1.72413793e-02,   1.58802178e-02, ...,
#            1.99637024e-02,   1.99637024e-02,   1.86025408e-02],
#         [  2.31112494e-02,   3.05891815e-02,   3.51503475e-02, ...,
#            1.68273395e-02,   1.30735413e-02,   1.09538349e-02],
#         [  3.26960574e+00,   3.27323861e+00,   3.28366897e+00, ...,
#            3.24860307e+00,   3.25636895e+00,   3.24349185e+00],
#         ...,
#         [  2.26870553e-03,   1.98241645e-03,   5.34750721e-03, ...,
#            2.03960124e-03,   1.81658533e-03,   2.24658876e-03],
#         [  5.72004987e-04,   1.15124983e-03,   2.74592791e-03, ...,
#            3.37072595e-03,   5.16213006e-03,   2.03199794e-02],
#         [  2.31824241e-02,   2.35590246e-02,   2.68077109e-02, ...,
#            3.47351982e-02,   3.20009029e-02,   2.81525999e-02]]),
#  array([[  1.20150188e-01,   1.46433041e-01,   1.38923655e-01, ...,
#            9.01126408e-02,   1.03879850e-01,   9.63704631e-02],
#         [  4.83305271e-02,   9.30590818e-02,   1.17601457e-01, ...,
#            9.20035778e-03,   1.08959303e-02,   8.62796222e-03],
#         [  3.01688184e+00,   3.27743887e+00,   3.31676370e+00, ...,
#            3.26651635e+00,   3.31326932e+00,   3.28553578e+00],
#         ...,
#         [  1.56107416e-03,   2.20006867e-03,   5.82099376e-04, ...,
#            2.29291375e-02,   3.22252277e-03,   4.86423556e-03],
#         [  1.25223156e-02,   1.45583991e-02,   3.95625004e-03, ...,
#            3.21874040e-02,   1.13577139e-01,   1.37156320e-01],
#         [  7.55427365e-03,   1.01373605e-02,   8.38965512e-03, ...,
#            3.88093443e-02,   3.22793775e-02,   3.85161137e-02]]),
# ...
#           -3.29161553e-01,  -4.02122789e-01,  -1.07956125e+00,
#           -1.03780766e+00,  -6.27499663e-01,  -6.60272333e-01],
#         [ -3.59355803e-01,  -4.28145228e-01,  -2.00096171e-01,
#           -1.46297804e-01,   1.32557296e-01,  -1.70007350e-02,
#            2.05511173e-01,   5.14506123e-01,   4.28757961e-01,
#            7.86731841e-01,   1.21602104e+00,   1.08623416e+00],
#         [ -3.49373705e-01,  -3.59445521e-01,  -1.53429159e-01,
#           -4.49369487e-01,  -1.76800776e-02,  -1.61385995e-01,
#           -2.06796828e-01,  -1.57797545e-01,   1.89987601e-01,
#            1.52033233e-01,   1.14529776e-02,  -1.46644664e-01],
#         [ -3.68685294e-01,  -3.38700670e-01,  -5.24931934e-01,
#           -1.09484717e+00,  -7.86269245e-01,  -1.07836100e+00,
#           -7.22289638e-01,  -6.00026447e-01,  -1.92976416e-01,
#           -1.48956440e-01,  -1.49514294e-01,  -1.88174155e-01],
#         [ -3.36310043e-01,  -2.85049741e-01,  -2.40204506e-01,
#           -3.29199098e-01,  -1.82049765e-01,   3.99026508e-02,
#           -8.43495556e-02,  -1.41291981e-01,  -3.58028504e-02,
#            1.42472826e-01,   1.03529321e-01,   2.33536619e-01],
#         [ -4.27926013e-01,  -3.41167609e-01,  -3.06750813e-01,
#            1.62361939e-01,   6.36731132e-02,   2.67837465e-01,
#            1.45661100e-01,   5.98840893e-02,   8.98984303e-02,
#           -1.26600713e-01,  -4.91210269e-01,   5.32128861e-02],
#         [ -4.87412275e-01,  -5.25049211e-01,  -5.98063666e-01,
#           -4.52390876e-01,  -6.02028227e-01,  -6.07887649e-01,
#           -5.91703592e-01,  -6.42686684e-01,  -5.37728415e-01,
#           -6.63044911e-02,  -6.87146287e-03,   4.05877978e-01],
#         [ -2.92838618e-01,  -3.88604627e-01,  -1.81913725e-01,
#           -1.13274093e-01,  -2.68399727e-02,  -1.54002590e-03,
#           -6.46103652e-02,   1.03595638e-01,   4.10017496e-01,
#            3.43948201e-01,   1.41829613e-01,  -9.18155762e-02],
#         [ -1.53703820e-01,  -2.35146725e-01,  -2.43877915e-01,
#           -4.11254780e-01,  -1.42875316e-01,   1.68883479e-01,
#           -1.31656174e-01,  -1.56380927e-01,  -2.48260592e-01,
#           -3.22083938e-01,  -2.01670505e-01,  -2.61567710e-01],
#         [  4.31991502e-03,   1.14136420e-02,   1.53783433e-02,
#            9.67622887e-03,   1.03246517e-02,   6.18823201e-03,
#            2.92130328e-03,   3.93583950e-03,   1.64128869e-03,
#            3.23812206e-03,   4.88484988e-03,   1.63938022e-02],
#         [  1.86918672e-03,   8.79598458e-04,   4.20476806e-04,
#            3.17169543e-03,   5.68600424e-03,   1.48095867e-02,
#            1.37684651e-02,   1.21133227e-03,   1.11527309e-03,
#            4.50676029e-03,   6.08586005e-04,   8.74261357e-03],
#         [  2.27401365e-01,   1.91227237e-01,   1.98352918e-01,
#            1.20432489e-01,   8.82511866e-02,   4.70509743e-02,
#            3.38422698e-02,   2.63806710e-02,   2.05615610e-02,
#            1.66198232e-02,   1.52180397e-02,   2.70407940e-03],
#         [  3.86463391e-02,   8.64051259e-02,   7.28701143e-02,
#            1.10952329e-01,   1.77892072e-02,   2.02424419e-03,
#            4.73070415e-03,   2.01244178e-02,   8.61386664e-02,
#            9.52594312e-02,   3.48721373e-02,   1.32302157e-03],
#         [  1.86767161e-02,   1.29865375e-02,   1.25247043e-02,
#            3.75013692e-03,   1.06797013e-02,   5.85147738e-03,
#            2.93450505e-03,   7.47014013e-03,   1.42113179e-02,
#            2.21618561e-02,   6.10439091e-02,   3.34317238e-02],
#         [  7.19013128e-03,   2.78568325e-03,   1.35753025e-03,
#            1.45793494e-02,   8.45880967e-03,   4.90712430e-03,
#            2.46744685e-03,   3.79943143e-03,   1.72747147e-02,
#            6.03021047e-03,   1.56782527e-02,   4.61825758e-02],
#         [  7.59245107e-03,   1.80683142e-03,   5.01630778e-03,
#            2.73472924e-03,   1.19869884e-02,   4.32995840e-03,
#            2.25252752e-03,   3.84820866e-03,   1.09073260e-03,
#            2.21632564e-02,   5.39893392e-02,   7.55547391e-02],
#         [  8.42042786e-05,   4.08421168e-05,   3.98058141e-05,
#            2.36751530e-04,   8.71229693e-04,   2.91056648e-03,
#            3.51297823e-03,   4.60349999e-04,   1.22595704e-03,
#            5.63494714e-03,   5.10196324e-03,   3.98341057e-03],
#         [  1.30863162e-03,   1.10698841e-03,   8.07514835e-04,
#            1.32025776e-02,   4.11227957e-02,   1.29317003e-02,
#            1.49392236e-02,   2.00920180e-02,   1.59134430e-03,
#            2.27218269e-03,   6.58064700e-04,   5.03542493e-03],
#         [  1.96074968e-03,   9.20979908e-04,   2.60190126e-03,
#            4.29155214e-03,   2.91718163e-03,   5.14157694e-03,
#            1.47912929e-03,   4.62783975e-03,   2.72079930e-02,
#            1.64968910e-02,   3.24196744e-03,   1.29370911e-02],
#         [  2.41712387e-03,   2.55821716e-03,   4.89230504e-03,
#            3.44646718e-03,   1.88572582e-02,   7.56939980e-02,
#            7.48020912e-02,   2.57006578e-02,   2.81328980e-03,
#            5.40579601e-03,   1.38504905e-02,   5.25490479e-03],
#         [  2.81883953e-04,   2.69651458e-04,   4.69352150e-05,
#            8.80173738e-04,   1.40998351e-03,   1.01150938e-03,
#            3.97927193e-03,   2.67010957e-03,   2.81300578e-03,
#            1.89481483e-03,   1.56497599e-02,   1.65464686e-02],
#         [  6.16426444e-02,   5.49395360e-02,   5.54326423e-02,
#            4.13083700e-02,   2.35542773e-02,   2.17927985e-02,
#            2.05293174e-02,   9.52837838e-03,   2.32330391e-02,
#            2.47525505e-02,   1.96245427e-02,   2.13850754e-02]]),
#  array([[  1.54264973e-02,   1.72413793e-02,   1.17967332e-02,
#            1.08892922e-02,   9.07441016e-03,   8.16696915e-03,
#            1.17967332e-02,   1.67876588e-02,   1.27041742e-02],
#         [  2.07524568e-03,   1.19872528e-03,   1.44291628e-02,
#            3.53093325e-02,   6.53009087e-02,   1.61417849e-01,
#            1.85456358e-01,   8.14673673e-02,   5.54134507e-02],
#         [  2.72907547e+00,   2.76325066e+00,   2.34746634e+00,
#            3.04182954e+00,   3.10702054e+00,   3.12348846e+00,
#            3.17174325e+00,   2.77445968e+00,   3.05640869e+00],
#         [  8.93302495e-02,   1.37762135e-01,   7.71762027e-02,
#            7.63037286e-02,   1.03651115e-01,   4.14309707e-02,
#            5.66758549e-02,   6.00989706e-02,   7.26135270e-02],
#         [  1.99233025e-01,   2.33122638e-01,   1.70602034e-01,
#            1.66349578e-01,   2.00723327e-01,   1.14943262e-01,
#            1.36646396e-01,   1.36339419e-01,   1.60378800e-01],
#         [  4.13979042e-02,   8.25428278e-02,   4.71492607e-02,
#            4.52617607e-02,   2.98958189e-02,   3.56372535e-03,
#            1.28375640e-02,   3.39843837e-02,   2.43890558e-02],
#         [  0.00000000e+00,   2.20297441e-02,   1.48075354e-02,
#            1.42501705e-02,   4.67788222e-03,   1.11733860e-02,
#            1.63555564e-02,   1.07353104e-02,   1.33167010e-02],
#         [  1.17967332e-02,   1.45190563e-02,   1.36116152e-02,
#            1.27041742e-02,   1.17967332e-02,   9.07441016e-03,
#            1.81488203e-02,   2.17785844e-02,   1.36116152e-02],
#         [ -3.05994382e+01,  -2.86861302e+01,  -2.76297588e+01,
#           -2.63117064e+01,  -2.50653827e+01,  -2.51084616e+01,
#           -2.39272940e+01,  -2.43302531e+01,  -2.57278984e+01],
#         [  3.55926634e+00,   3.26373589e+00,   3.57007935e+00,
#            3.69857412e+00,   3.26400222e+00,   5.04089727e+00,
#            4.62066302e+00,   4.74782347e+00,   4.70005214e+00],
#         [  1.87895904e+00,   7.94530504e-01,   1.86267337e+00,
#            1.70423996e+00,   1.13650705e+00,   8.59768623e-01,
#            9.32885276e-01,   9.80300506e-01,   8.38029969e-01],
#         [  7.38418224e-01,   3.43143913e-01,   1.04345441e+00,
#            5.93841575e-01,   5.60154662e-01,  -3.35983738e-01,
#            8.75525713e-02,  -9.02652384e-02,   2.12181635e-01],
#         [  6.48354148e-01,  -1.38167628e-01,   4.78905437e-01,
#            3.53455767e-01,   2.49137929e-01,  -4.97245499e-01,
#           -1.23011052e+00,  -1.52554558e+00,  -9.83357414e-01],
#         [ -1.98421099e-03,  -3.09088049e-01,  -4.84310325e-01,
#           -2.98592130e-01,  -2.70974101e-02,   2.25685961e-02,
#            1.91441360e-01,   3.45244266e-02,   1.29148570e-01],
#         [ -2.89932624e-01,  -4.58397544e-01,  -8.95469590e-01,
#           -7.27832708e-01,  -4.38349741e-01,   6.39148211e-02,
#            4.58046393e-01,   4.46304784e-01,   9.09120089e-02],
#         [ -3.19144490e-01,  -2.36582249e-01,  -4.10718710e-01,
#           -3.45909748e-01,  -3.77638355e-01,  -5.88268337e-02,
#            2.08403110e-02,  -1.66192577e-01,  -2.40564160e-01],
#         [ -5.88144912e-01,  -2.13123124e-01,  -5.65884479e-01,
#           -5.24396057e-01,  -5.63536313e-01,  -4.21922739e-01,
#           -1.56206557e-02,  -1.28172797e-01,   1.01334306e-01],
#         [  9.01680206e-02,  -4.31283525e-02,   1.47846490e-01,
#            2.22570370e-01,  -9.44422181e-02,   1.36202942e-01,
#           -4.72785760e-01,  -4.07318328e-01,  -6.87100222e-01],
#         [ -4.87856728e-01,   1.34048003e-01,  -4.80775593e-01,
#           -4.90104357e-01,  -4.72368042e-01,  -8.37178921e-01,
#           -6.35057631e-01,  -4.55603502e-01,  -4.10927824e-01],
#         [  6.57264996e-02,   1.90671318e-01,   6.24666258e-01,
#            3.27310347e-01,  -6.83930058e-02,  -2.42634703e-03,
#           -5.42891858e-02,   8.21843640e-02,   1.35063027e-02],
#         [ -3.61058565e-01,  -1.33390831e-02,  -3.44760112e-02,
#           -3.15375412e-01,  -3.58044638e-01,  -2.35232369e-01,
#           -4.41075099e-01,  -4.50704673e-01,  -5.89145758e-01],
#         [  3.08084157e-02,   8.72701868e-03,   2.55133282e-02,
#            5.70157886e-03,   1.28292489e-02,   2.64384775e-02,
#            5.85051273e-02,   4.02230773e-02,   1.67092774e-02],
#         [  3.18409264e-05,   8.01938568e-04,   1.42659726e-05,
#            1.17879679e-04,   1.34455273e-04,   9.17506038e-04,
#            1.39772032e-03,   3.01282379e-03,   1.17940412e-03],
#         [  2.03962171e-02,   3.64650622e-02,   1.22091716e-02,
#            5.64799533e-03,   4.92948319e-03,   5.14395513e-03,
#            1.77388546e-02,   3.41417412e-02,   7.71237376e-03],
#         [  8.51669952e-03,   3.69087234e-03,   4.47978469e-03,
#            3.46783934e-03,   4.19514948e-03,   1.80698435e-03,
#            5.96461062e-03,   1.49103559e-02,   7.28598693e-03],
#         [  8.85262980e-03,   1.19392227e-02,   2.94228056e-02,
#            4.61915505e-02,   2.34473267e-02,   5.51363916e-03,
#            6.48394098e-03,   1.81792712e-02,   1.23186946e-02],
#         [  2.51469267e-02,   5.69904115e-02,   1.08764990e-01,
#            1.90544513e-02,   4.52257197e-03,   3.86358715e-03,
#            1.05713633e-02,   1.37714019e-02,   2.03230020e-03],
#         [  1.41111155e-02,   5.67222190e-02,   2.38551742e-02,
#            1.46171013e-02,   3.40483264e-03,   3.90713391e-03,
#            3.57134880e-03,   1.78743236e-02,   1.29103791e-02],
#         [  1.77990775e-05,   2.59003169e-04,   1.11632863e-04,
#            7.19548040e-05,   9.00367136e-05,   7.12821835e-05,
#            1.97315851e-05,   3.05730528e-05,   8.74947138e-06],
#         [  3.43271125e-04,   2.23542318e-02,   2.29728330e-03,
#            1.40794195e-03,   3.07621090e-04,   1.46086422e-03,
#            1.20620647e-04,   1.20143630e-03,   1.29687521e-03],
#         [  2.03654356e-02,   4.52137754e-03,   1.93715626e-02,
#            1.46953297e-02,   1.07918638e-02,   1.23682955e-03,
#            5.68308649e-03,   2.17070119e-02,   2.37356047e-02],
#         [  1.55455694e-01,   6.79104820e-02,   6.42013087e-02,
#            1.55309355e-01,   1.95622525e-01,   2.06254507e-01,
#            1.48474241e-01,   9.41132075e-02,   1.70353983e-01],
#         [  3.11700726e-05,   1.01963435e-03,   1.22562139e-04,
#            1.60778813e-04,   7.48245715e-05,   9.56565755e-04,
#            9.32572860e-03,   3.33365072e-03,   2.49353789e-03],
#         [  4.10324203e-02,   2.41916898e-02,   3.10390820e-02,
#            4.20414255e-02,   5.28555956e-02,   5.61301142e-02,
#            4.09537940e-02,   2.49223606e-02,   4.54228975e-02]]),
#  array([[  2.35934664e-02,   1.40653358e-02,   1.58802178e-02, ...,
#            2.40471869e-02,   1.72413793e-02,   1.58802178e-02],
#         [  4.81272883e-03,   2.32308391e-03,   2.56654507e-03, ...,
#            4.55236384e-03,   4.33651264e-03,   4.20461169e-03],
#         [  2.75268326e+00,   2.98151407e+00,   2.98180318e+00, ...,
#            2.97024026e+00,   3.08789536e+00,   3.16371730e+00],
#         ...,
#         [  2.11915790e-02,   3.20348921e-02,   7.99818236e-03, ...,
#            2.49015653e-02,   7.49673009e-02,   9.12198225e-02],
#         [  2.09328349e-02,   1.71832773e-03,   2.31568736e-02, ...,
#            1.12148259e-03,   5.14220532e-04,   1.32936787e-03],
#         [  2.12064096e-02,   3.50867475e-02,   1.74347300e-02, ...,
#            2.79029093e-02,   2.03507200e-02,   2.41309192e-02]]),
#  array([[  3.35299456e-01,   2.84029038e-01,   2.75408348e-01, ...,
#            3.13067151e-02,   3.31215971e-02,   2.81306715e-02],
#         [  7.17161718e-03,   9.42943619e-05,   3.03307971e-05, ...,
#            9.84803282e-03,   1.09677596e-02,   9.54457861e-03],
#         [  1.59688752e+00,   2.67114948e+00,   3.28174375e+00, ...,
#            3.10051395e+00,   3.09505168e+00,   3.07366586e+00],
#         ...,
#         [  4.46101132e-04,   1.34877096e-03,   1.14912630e-03, ...,
#            2.13297460e-02,   2.59918274e-02,   7.04480153e-02],
#         [  1.44338332e-04,   5.31560580e-04,   2.43056379e-04, ...,
#            7.82273641e-03,   2.82889015e-03,   9.24750022e-04],
#         [  7.86521096e-04,   2.11166249e-03,   4.64401499e-03, ...,
#            5.86032833e-03,   2.38372997e-02,   2.23826150e-02]]),
#  array([[  2.85843920e-02,   2.35934664e-02,   2.22323049e-02, ...,
#            1.63339383e-02,   1.27041742e-02,   1.17967332e-02],
#         [  5.80144288e-02,   6.14750372e-02,   3.21918090e-02, ...,
#            5.62202597e-03,   8.54865271e-03,   9.09566917e-03],
#         [  3.03232843e+00,   3.20119474e+00,   2.56823093e+00, ...,
#            3.14856904e+00,   3.12675789e+00,   3.15909201e+00],
#         ...,
#         [  3.17054728e-03,   3.31150530e-03,   5.56772572e-03, ...,
#            8.56170740e-02,   1.06503786e-01,   1.32437901e-01],
#         [  1.90931530e-03,   4.36277859e-04,   4.71900293e-03, ...,
#            1.06515711e-03,   1.76853162e-03,   2.67131832e-03],
#         [  1.40064859e-02,   1.45673985e-02,   1.42945518e-02, ...,
#            2.51762322e-02,   2.84845701e-02,   3.65483349e-02]]),
#  array([[  2.43647913e-01,   2.37749546e-01,   2.30036298e-01, ...,
#            2.54083485e-02,   2.58620690e-02,   2.26860254e-02],
#         [  1.12830790e-02,   1.97265798e-04,   9.92350087e-05, ...,
#            1.82038893e-02,   1.59267181e-02,   1.29926242e-02],
#         [  1.22452390e+00,   3.14602546e+00,   3.19857646e+00, ...,
#            3.29599458e+00,   3.30753017e+00,   3.28437149e+00],
#         ...,
#         [  1.30620238e-03,   2.36208175e-03,   3.33062787e-03, ...,
#            9.66287286e-04,   6.33415844e-04,   4.51357434e-03],
#         [  1.81664379e-03,   1.80660738e-03,   8.66138298e-04, ...,
#            1.13070356e-01,   1.24826006e-01,   1.49828337e-01],
#         [  9.88056793e-04,   1.45593314e-03,   2.63799549e-03, ...,
#            3.86591461e-02,   3.97724626e-02,   4.09724648e-02]]),
#  array([[  1.99637024e-02,   8.89292196e-02,   1.92377495e-01, ...,
#            9.98185118e-03,   1.45190563e-02,   2.35934664e-02],
#         [  1.95048651e-02,   7.36543462e-03,   2.33149882e-03, ...,
#            9.21682912e-03,   1.03833648e-02,   1.06005135e-02],
#         [  3.13998159e+00,   2.87263797e+00,   3.23555615e+00, ...,
#            3.21035397e+00,   3.21923801e+00,   3.22270268e+00],
#         ...,
#         [  3.40159050e-03,   2.28142502e-02,   5.77340743e-03, ...,
#            1.65781647e-01,   1.45395824e-01,   1.34337360e-01],
#         [  1.20768005e-02,   4.99477047e-02,   1.12237603e-02, ...,
#            2.82822622e-03,   3.78266451e-03,   4.10585194e-03],
#         [  3.73037756e-02,   2.34473044e-02,   1.32065758e-02, ...,
#            4.46139491e-02,   3.88559995e-02,   3.57200829e-02]])]

# %%
X_melfs.shape, Y_mels.shape
# Out:
# ((1574, 128), (1574,))

# %% [markdown]
# #### Splitting Data for TRAINing & TESTing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_melfs,Y_mels, test_size=0.2,  random_state=0)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1259, 128), (1259,), (315, 128), (315,))

# %% [markdown]
# ### SVM Models (for Classification of Dialects)

# %% [markdown]
# - Linear Kernel

# %%
clf_fold = svm.SVC(kernel='linear', C=1)

scores_lsvm =cross_val_score(clf_fold,X_melfs,Y_mels, cv=10)

scores_lsvm
# Out:
# array([ 0.3125    ,  0.24375   ,  0.3       ,  0.34591195,  0.29299363,
#         0.32051282,  0.30128205,  0.35897436,  0.42580645,  0.33548387])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_lsvm.mean(), scores_lsvm.std() * 2))
# Out:
# Accuracy: 0.32 (+/- 0.09)

# %% [markdown]
# - Radial basis function - "rbf" Kernel

# %%
clf_rbf = svm.SVC(kernel='rbf', C=1)

scores_rbf_svm_melS =cross_val_score(clf_rbf,X_melfs,Y_mels, cv=10)

scores_rbf_svm_melS
# Out:
# array([ 0.2875    ,  0.3       ,  0.28125   ,  0.41509434,  0.33121019,
#         0.30769231,  0.30769231,  0.34615385,  0.30967742,  0.30967742])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_rbf_svm_melS.mean(), scores_rbf_svm_melS.std() * 2))
# Out:
# Accuracy: 0.32 (+/- 0.07)

# %% [markdown]
# ## Prosodic Features

# %% [markdown]
# #### Path_to_Features for Loading

# %%
with open(path_to_data + 'Prosodic_Features/prosodic_labels_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    y_pros= pickle.load(fp)
    
with open(path_to_data + 'Prosodic_Features/prosodic_features_' + str(max_classes-1) + '.csv',mode='rb') as fp: 
    X_pros= pickle.load(fp,encoding='latin1')

# %%
X_profs = np.array(X_pros)
Y_prols = np.array(y_pros)

# %%
X_profs.shape, Y_prols.shape
# Out:
# ((680, 3), (680,))

# %% [markdown]
# #### Splitting Data for TRAINing & TESTing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_profs,Y_prols, test_size=0.2,  random_state=0)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1259, 3), (1259,), (315, 3), (315,))

# %% [markdown]
# ### SVM Models (for Classification of Dialects)

# %% [markdown]
# - Linear Kernel

# %%
clf_fold = svm.SVC(kernel='linear', C=1)

scores_lsvm_pro =cross_val_score(clf_fold,X_profs,Y_prols, cv=10)

scores_lsvm_pro

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_lsvm_pro.mean(), scores_lsvm_pro.std() * 2))

# %% [markdown]
# - Radial basis function - "rbf" Kernel

# %%
clf_rbf = svm.SVC(kernel='rbf', C=1)

scores_rbf_svm_pros =cross_val_score(clf_rbf,X_melfs,Y_mels, cv=10)

scores_rbf_svm_pros

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores_rbf_svm_pros.mean(), scores_rbf_svm_pros.std() * 2))

# %% [markdown]
# ## Transform the Matrix Shapes
#   - XiV_features = np.array(X_iV).T
#   - YiV_labels = np.array(Y_iV).T
#
# Here, Tranform is being done to Reshape the Martix Shapes, Such that (#Samples, #features)

# %%
XiV_features = np.array(X_iV).T
YiV_labels = np.array(Y_iV).T

# %% [markdown]
# Here,below you can See the Difference:

# %%
XiV_features.shape, YiV_labels.shape
# Out:
# ((400, 350), (400, 1))

# %%
YiV_labels = YiV_labels.reshape(400,);

# %% [markdown]
# #### Above Reshape() is used to Avoid this following Error
# - /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## Models (for Classification of Dialects)
#    - SVM
#    - CNN
